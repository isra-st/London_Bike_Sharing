# %%
import pandas as pd
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import os
import datetime as dt
from datetime import datetime
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Analysis_Sharing_Bike.ipynb',
#  'Brazilian_Ecomerce',
#  'Country_food.ipynb',
#  'country_food.png',
#  'Fish.csv',
#  'london_merged.csv',
#  'wfp_market_food_prices.csv',
#  'wfp_market_food_prices2.csv']

# %%
df = pd.read_csv('london_merged.csv')

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %% [markdown]
# ```Pyhton
#
# ['timestamp', 'minutes', 'temperature', 'temperature_feels', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season']
# ```

# %%
df.columns = ['timestamp', 'number', 'temperature', 'temperature_feels', 'hum', 'wind_speed', 'weather_code',
       'is_holiday', 'is_weekend', 'season']

# %%
df.columns
# Out:
# Index(['timestamp', 'number', 'temperature', 'temperature_feels', 'hum',
#        'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
df
# Out:
#                  timestamp  number  temperature  temperature_feels    hum  \
# 0      2015-01-04 00:00:00     182          3.0                2.0   93.0
# 1      2015-01-04 01:00:00     138          3.0                2.5   93.0
# 2      2015-01-04 02:00:00     134          2.5                2.5   96.5
# 3      2015-01-04 03:00:00      72          2.0                2.0  100.0
# 4      2015-01-04 04:00:00      47          2.0                0.0   93.0
# ...                    ...     ...          ...                ...    ...
# 17409  2017-01-03 19:00:00    1042          5.0                1.0   81.0
# 17410  2017-01-03 20:00:00     541          5.0                1.0   81.0
# 17411  2017-01-03 21:00:00     337          5.5                1.5   78.5
# 17412  2017-01-03 22:00:00     224          5.5                1.5   76.0
# 17413  2017-01-03 23:00:00     139          5.0                1.0   76.0
#
#        wind_speed  weather_code  is_holiday  is_weekend  season
# 0             6.0           3.0         0.0         1.0     3.0
# 1             5.0           1.0         0.0         1.0     3.0
# 2             0.0           1.0         0.0         1.0     3.0
# 3             0.0           1.0         0.0         1.0     3.0
# 4             6.5           1.0         0.0         1.0     3.0
# ...           ...           ...         ...         ...     ...
# 17409        19.0           3.0         0.0         0.0     3.0
# 17410        21.0           4.0         0.0         0.0     3.0
# 17411        24.0           4.0         0.0         0.0     3.0
# 17412        23.0           4.0         0.0         0.0     3.0
# 17413        22.0           2.0         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %% [markdown]
# ```Python
#
# df['date/time'] = pd.to_datetime(df['date/time'], format = '%d/%m/%Y %H:%M:%S')
#
# df['Day of Week'] = df['date/time'].dt.weekday_name
#
#
# import pandas as pd
# from datetime import datetime
#
# data = {'stuff': [0,1,2,3]}
# df = pd.DataFrame(data)
#
# df.index = pd.to_datetime(['2020-07-07 19:03:38', '2020-07-08 18:50:40',
#                 '2020-07-24 4:20:13', '2020-07-25 4:20:13']).strftime('%d %H:%M')
#
# print(df)
#
#           stuff
# 07 19:03      0
# 08 18:50      1
# 24 04:20      2
# 25 04:20      3
# ```

# %%
df['month'] = df.timestamp.apply(lambda x : x.strftime('%m'))

# %%
df.columns
# Out:
# Index(['timestamp', 'month', 'number', 'temperature', 'temperature_feels',
#        'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
#        'season', 'year', 'day'],
#       dtype='object')

# %%
column_names = ['timestamp', 'month', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %%
df = df.reindex(columns=column_names)

# %%
df = df.reindex(columns=column_names)

# %%
df['year'] = df.timestamp.apply(lambda x : x.strftime('20%y'))

# %%
df['day'] = df.timestamp.apply(lambda x : x.strftime('%d'))

# %%
column_names = ['timestamp', 'year', 'month', 'day', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %%
df = df.reindex(columns=column_names)

# %%
df['day_name'] = df['timestamp'].dt.day_name()

# %%
df.columns
# Out:
# Index(['timestamp', 'year', 'month', 'day', 'number', 'temperature',
#        'temperature_feels', 'hum', 'wind_speed', 'weather_code', 'is_holiday',
#        'is_weekend', 'season', 'day_name'],
#       dtype='object')

# %%
column_names = ['timestamp', 'year', 'month', 'day', 'day_name', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %%
df = df.reindex(columns=column_names)

# %%
column_names = ['timestamp', 'year', 'month', 'day_month', 'day_name', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %%
df.set_axis(column_names, axis='columns', inplace=True)

# %%
df['month'] = pd.to_datetime(df['month'], format='%m').dt.month_name().str.slice(stop=3)

# %%
df.to_csv('london_merged_v1.csv')

# %%
df = pd.read_csv('london_merged_v1.csv')

# %%
df = df.reset_index()

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.to_csv('london_merged_v1.csv', index=False)

# %%
df = pd.read_csv('london_merged_v1.csv')

# %%
# Out:
#        index            timestamp  year month  day_month day_name  number  \
# 0          0  2015-01-04 00:00:00  2015   Jan          4   Sunday     182
# 1          1  2015-01-04 01:00:00  2015   Jan          4   Sunday     138
# 2          2  2015-01-04 02:00:00  2015   Jan          4   Sunday     134
# 3          3  2015-01-04 03:00:00  2015   Jan          4   Sunday      72
# 4          4  2015-01-04 04:00:00  2015   Jan          4   Sunday      47
# ...      ...                  ...   ...   ...        ...      ...     ...
# 17409  17409  2017-01-03 19:00:00  2017   Jan          3  Tuesday    1042
# 17410  17410  2017-01-03 20:00:00  2017   Jan          3  Tuesday     541
# 17411  17411  2017-01-03 21:00:00  2017   Jan          3  Tuesday     337
# 17412  17412  2017-01-03 22:00:00  2017   Jan          3  Tuesday     224
# 17413  17413  2017-01-03 23:00:00  2017   Jan          3  Tuesday     139
#
#        temperature  temperature_feels    hum  wind_speed  weather_code  \
# 0              3.0                2.0   93.0         6.0           3.0
# 1              3.0                2.5   93.0         5.0           1.0
# 2              2.5                2.5   96.5         0.0           1.0
# 3              2.0                2.0  100.0         0.0           1.0
# 4              2.0                0.0   93.0         6.5           1.0
# ...            ...                ...    ...         ...           ...
# 17409          5.0                1.0   81.0        19.0           3.0
# 17410          5.0                1.0   81.0        21.0           4.0
# 17411          5.5                1.5   78.5        24.0           4.0
# 17412          5.5                1.5   76.0        23.0           4.0
# 17413          5.0                1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 15 columns]
