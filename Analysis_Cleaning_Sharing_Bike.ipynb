# %%
import pandas as pd
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import os
import datetime as dt
from datetime import datetime
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'Analysis_Cleaning_Sharing_Bike.ipynb',
#  'Data',
#  'london_merged_v1.csv',
#  'README.md']

# %% [markdown]
# ### Overview of the DataSet

# %%
os.getcwd()
# Out:
# 'D:\\Repositories\\london_bike_sharing'

# %%
df = pd.read_csv('.\data/london_merged.csv')

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %% [markdown]
# ### Renaming Columns

# %%
df.columns = ['timestamp', 'number', 'temperature', 'temperature_feels', 'hum', 'wind_speed', 'weather_code',
       'is_holiday', 'is_weekend', 'season']

# %%
df.columns
# Out:
# Index(['timestamp', 'number', 'temperature', 'temperature_feels', 'hum',
#        'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
pd.to_datetime(df['timestamp'])
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %% [markdown]
# ### Converting to Datetime the dates

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %% [markdown]
# ### Adding Year, Month, Day, to the dataset

# %%
df['month'] = df.timestamp.apply(lambda x : x.strftime('%m'))

# %%
df.columns
# Out:
# Index(['timestamp', 'number', 'temperature', 'temperature_feels', 'hum',
#        'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season',
#        'month'],
#       dtype='object')

# %%
column_names = ['timestamp', 'month', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %% [markdown]
# * Reorganizing the columns

# %%
df = df.reindex(columns=column_names)

# %% [markdown]
# * Year, Days, Day_name, Week number

# %%
df['year'] = df.timestamp.apply(lambda x : x.strftime('20%y'))

# %%
df['day'] = df.timestamp.apply(lambda x : x.strftime('%d'))

# %%
column_names = ['timestamp', 'year', 'month', 'day', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %%
df = df.reindex(columns=column_names)

# %%
df['day_name'] = df['timestamp'].dt.day_name()

# %%
df['week_number'] = df.timestamp.apply(lambda x : x.strftime('%U'))

# %%
df['time'] = df.timestamp.apply(lambda x : x.strftime('%H:%M'))

# %%
df['date'] = df.timestamp.apply(lambda x : x.strftime('%y-%m-%d'))

# %% [markdown]
# * Reorganizing the columns again

# %%
df.columns
# Out:
# Index(['timestamp', 'year', 'month', 'day', 'number', 'temperature',
#        'temperature_feels', 'hum', 'wind_speed', 'weather_code', 'is_holiday',
#        'is_weekend', 'season', 'day_name', 'week_number', 'time', 'date'],
#       dtype='object')

# %%
column_names = ['timestamp','date', 'year', 'month', 'day', 'day_name', 'week_number', 'time', 'number', 'temperature',
       'temperature_feels', 'hum', 'wind_speed', 'weather_code', 'is_holiday',
       'is_weekend', 'season']

# %%
df = df.reindex(columns=column_names)

# %%
df
# Out:
#                 timestamp      date  year month day day_name week_number  \
# 0     2015-01-04 00:00:00  15-01-04  2015    01  04   Sunday          01
# 1     2015-01-04 01:00:00  15-01-04  2015    01  04   Sunday          01
# 2     2015-01-04 02:00:00  15-01-04  2015    01  04   Sunday          01
# 3     2015-01-04 03:00:00  15-01-04  2015    01  04   Sunday          01
# 4     2015-01-04 04:00:00  15-01-04  2015    01  04   Sunday          01
# ...                   ...       ...   ...   ...  ..      ...         ...
# 17409 2017-01-03 19:00:00  17-01-03  2017    01  03  Tuesday          01
# 17410 2017-01-03 20:00:00  17-01-03  2017    01  03  Tuesday          01
# 17411 2017-01-03 21:00:00  17-01-03  2017    01  03  Tuesday          01
# 17412 2017-01-03 22:00:00  17-01-03  2017    01  03  Tuesday          01
# 17413 2017-01-03 23:00:00  17-01-03  2017    01  03  Tuesday          01
#
#         time  number  temperature  temperature_feels    hum  wind_speed  \
# 0      00:00     182          3.0                2.0   93.0         6.0
# 1      01:00     138          3.0                2.5   93.0         5.0
# 2      02:00     134          2.5                2.5   96.5         0.0
# 3      03:00      72          2.0                2.0  100.0         0.0
# 4      04:00      47          2.0                0.0   93.0         6.5
# ...      ...     ...          ...                ...    ...         ...
# 17409  19:00    1042          5.0                1.0   81.0        19.0
# 17410  20:00     541          5.0                1.0   81.0        21.0
# 17411  21:00     337          5.5                1.5   78.5        24.0
# 17412  22:00     224          5.5                1.5   76.0        23.0
# 17413  23:00     139          5.0                1.0   76.0        22.0
#
#        weather_code  is_holiday  is_weekend  season
# 0               3.0         0.0         1.0     3.0
# 1               1.0         0.0         1.0     3.0
# 2               1.0         0.0         1.0     3.0
# 3               1.0         0.0         1.0     3.0
# 4               1.0         0.0         1.0     3.0
# ...             ...         ...         ...     ...
# 17409           3.0         0.0         0.0     3.0
# 17410           4.0         0.0         0.0     3.0
# 17411           4.0         0.0         0.0     3.0
# 17412           4.0         0.0         0.0     3.0
# 17413           2.0         0.0         0.0     3.0
#
# [17414 rows x 17 columns]

# %%
df
# Out:
#                 timestamp      date  year month day day_name week_number  \
# 0     2015-01-04 00:00:00  15-01-04  2015    01  04   Sunday          01
# 1     2015-01-04 01:00:00  15-01-04  2015    01  04   Sunday          01
# 2     2015-01-04 02:00:00  15-01-04  2015    01  04   Sunday          01
# 3     2015-01-04 03:00:00  15-01-04  2015    01  04   Sunday          01
# 4     2015-01-04 04:00:00  15-01-04  2015    01  04   Sunday          01
# ...                   ...       ...   ...   ...  ..      ...         ...
# 17409 2017-01-03 19:00:00  17-01-03  2017    01  03  Tuesday          01
# 17410 2017-01-03 20:00:00  17-01-03  2017    01  03  Tuesday          01
# 17411 2017-01-03 21:00:00  17-01-03  2017    01  03  Tuesday          01
# 17412 2017-01-03 22:00:00  17-01-03  2017    01  03  Tuesday          01
# 17413 2017-01-03 23:00:00  17-01-03  2017    01  03  Tuesday          01
#
#         time  number  temperature  temperature_feels    hum  wind_speed  \
# 0      00:00     182          3.0                2.0   93.0         6.0
# 1      01:00     138          3.0                2.5   93.0         5.0
# 2      02:00     134          2.5                2.5   96.5         0.0
# 3      03:00      72          2.0                2.0  100.0         0.0
# 4      04:00      47          2.0                0.0   93.0         6.5
# ...      ...     ...          ...                ...    ...         ...
# 17409  19:00    1042          5.0                1.0   81.0        19.0
# 17410  20:00     541          5.0                1.0   81.0        21.0
# 17411  21:00     337          5.5                1.5   78.5        24.0
# 17412  22:00     224          5.5                1.5   76.0        23.0
# 17413  23:00     139          5.0                1.0   76.0        22.0
#
#        weather_code  is_holiday  is_weekend  season
# 0               3.0         0.0         1.0     3.0
# 1               1.0         0.0         1.0     3.0
# 2               1.0         0.0         1.0     3.0
# 3               1.0         0.0         1.0     3.0
# 4               1.0         0.0         1.0     3.0
# ...             ...         ...         ...     ...
# 17409           3.0         0.0         0.0     3.0
# 17410           4.0         0.0         0.0     3.0
# 17411           4.0         0.0         0.0     3.0
# 17412           4.0         0.0         0.0     3.0
# 17413           2.0         0.0         0.0     3.0
#
# [17414 rows x 17 columns]

# %% [markdown]
# * Changing number of month to name of the month

# %%
df['month'] = pd.to_datetime(df['month'], format='%m').dt.month_name().str.slice(stop=3)

# %%
df.columns
# Out:
# Index(['timestamp', 'date', 'year', 'month', 'day', 'day_name', 'week_number',
#        'time', 'number', 'temperature', 'temperature_feels', 'hum',
#        'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
df.columns = ['timestamp', 'date', 'year', 'month', 'day', 'day_name', 'week_number',
       'time', 'bike_number', 'temperature', 'temperature_feels', 'hum',
       'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season']

# %%
df.to_csv('london_merged_v1.csv')

# %%
Null Value

# %% [markdown]
# ### Saving the updates and cleanning in a new Data Set

# %%
df = pd.read_csv('london_merged_v1.csv')

# %%
df = df.reset_index()

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# 12869           26  17:00         2608         19.5               19.5  56.0
# 9324             4  09:00         1792         11.5               11.5  77.0
# 730              5  11:00          575          2.5               -1.0  87.0
# 13466           29  14:00         1768         24.5               24.5  43.0
# 14430           35  01:00          221         17.5               17.5  70.5
# 4592            28  20:00         1125         19.0               19.0  91.0
# 15938           44  11:00         1056         10.0                8.0  58.0
# 8163            49  20:00          737          8.5                5.5  73.5
# 6301            38  13:00         1507         17.5               17.5  54.0
#
#        wind_speed  weather_code  is_holiday  is_weekend  season
# 2510         16.0           1.0         0.0         1.0     0.0
# 6424         24.0           1.0         0.0         0.0     2.0
# 13452        20.5           1.0         0.0         0.0     1.0
# 16121        15.0           2.0         0.0         0.0     2.0
# 6708         21.0           2.0         0.0         1.0     2.0
# 6978          2.0           4.0         0.0         0.0     2.0
# 5960          6.0           1.0         0.0         0.0     2.0
# 12358        10.0           4.0         0.0         1.0     1.0
# 2490         18.0           3.0         0.0         1.0     0.0
# 4218         12.0           1.0         0.0         0.0     1.0
# 5289         16.0           4.0         0.0         0.0     1.0
# 7713          7.5           1.0         0.0         0.0     2.0
# 10175         6.5           1.0         0.0         1.0     0.0
# 13972        20.0           1.0         0.0         0.0     1.0
# 3196         21.5           2.0         0.0         1.0     0.0
# 7786          6.5           1.0         0.0         0.0     2.0
# 16602        16.0           1.0         0.0         0.0     3.0
# 4639         27.0           1.0         0.0         0.0     1.0
# 1039          8.0           3.0         0.0         0.0     3.0
# 16257        16.0           7.0         0.0         0.0     2.0
# 13940        15.0           2.0         0.0         0.0     1.0
# 14272         5.0           1.0         0.0         0.0     1.0
# 4277         21.0           1.0         0.0         0.0     1.0
# 10380        21.5           1.0         0.0         1.0     0.0
# 2749         19.0           1.0         0.0         0.0     0.0
# 720           9.0           4.0         0.0         0.0     3.0
# 1225         32.0           2.0         0.0         0.0     3.0
# 6397         30.0           1.0         0.0         0.0     2.0
# 10867        13.0           1.0         0.0         1.0     0.0
# 11924        20.0           2.0         0.0         0.0     0.0
# 10746        27.0           1.0         0.0         0.0     0.0
# 7160         10.0           7.0         0.0         0.0     2.0
# 6932         14.0           1.0         0.0         0.0     2.0
# 14157        18.5           7.0         0.0         0.0     1.0
# 14494        26.0           3.0         0.0         1.0     2.0
# 10431        19.0           3.0         0.0         0.0     0.0
# 7780          7.5           2.0         0.0         0.0     2.0
# 2964         17.5           1.0         0.0         0.0     0.0
# 13356        18.0           2.0         0.0         1.0     1.0
# 9789         16.0           7.0         0.0         0.0     3.0
# 9901         14.0           2.0         0.0         0.0     3.0
# 12869        28.0           2.0         0.0         1.0     1.0
# 9324         36.0           3.0         0.0         0.0     3.0
# 730          13.0           3.0         0.0         0.0     3.0
# 13466         6.5           2.0         0.0         0.0     1.0
# 14430         6.5           1.0         0.0         0.0     1.0
# 4592         11.0           7.0         0.0         0.0     1.0
# 15938        14.0           1.0         0.0         0.0     2.0
# 8163         17.0           1.0         0.0         0.0     3.0
# 6301         24.0           2.0         0.0         0.0     2.0

# %% [markdown]
# ### Null Values

# %%
df.isna().sum()
