# %%
import pandas as pd
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import os
import datetime as dt
from datetime import datetime
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'Analysis_Cleaning_Sharing_Bike.ipynb',
#  'Data',
#  'london_merged_v1.csv',
#  'README.md']

# %% [markdown]
# ### Overview of the DataSet

# %%
os.getcwd()
# Out:
# 'D:\\Repositories\\london_bike_sharing'

# %%
df = pd.read_csv('.\data/london_merged.csv')

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %% [markdown]
# ### Renaming Columns

# %%
df.columns = ['timestamp', 'number', 'temperature', 'temperature_feels', 'hum', 'wind_speed', 'weather_code',
       'is_holiday', 'is_weekend', 'season']

# %%
df.columns
# Out:
# Index(['timestamp', 'number', 'temperature', 'temperature_feels', 'hum',
#        'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
pd.to_datetime(df['timestamp'])
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %% [markdown]
# ### Converting to Datetime the dates

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %% [markdown]
# ### Adding Year, Month, Day, to the dataset

# %%
df['month'] = df.timestamp.apply(lambda x : x.strftime('%m'))

# %%
df.columns
# Out:
# Index(['timestamp', 'number', 'temperature', 'temperature_feels', 'hum',
#        'wind_speed', 'weather_code', 'is_holiday', 'is_weekend', 'season',
#        'month'],
#       dtype='object')

# %%
column_names = ['timestamp', 'month', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %% [markdown]
# * Reorganizing the columns

# %%
df = df.reindex(columns=column_names)

# %% [markdown]
# * Year, Days, Day_name, Week number

# %%
df['year'] = df.timestamp.apply(lambda x : x.strftime('20%y'))

# %%
df['day'] = df.timestamp.apply(lambda x : x.strftime('%d'))

# %%
column_names = ['timestamp', 'year', 'month', 'day', 'number', 'temperature', 'temperature_feels',
       'hum', 'wind_speed', 'weather_code', 'is_holiday', 'is_weekend',
       'season']

# %%
df = df.reindex(columns=column_names)

# %%
df['day_name'] = df['timestamp'].dt.day_name()

# %%
df['week_number'] = df.timestamp.apply(lambda x : x.strftime('%U'))

# %%
df
# Out:
#                 timestamp  year month day  number  temperature  \
# 0     2015-01-04 00:00:00  2015    01  04     182          3.0
# 1     2015-01-04 01:00:00  2015    01  04     138          3.0
# 2     2015-01-04 02:00:00  2015    01  04     134          2.5
# 3     2015-01-04 03:00:00  2015    01  04      72          2.0
# 4     2015-01-04 04:00:00  2015    01  04      47          2.0
# ...                   ...   ...   ...  ..     ...          ...
# 17409 2017-01-03 19:00:00  2017    01  03    1042          5.0
# 17410 2017-01-03 20:00:00  2017    01  03     541          5.0
# 17411 2017-01-03 21:00:00  2017    01  03     337          5.5
# 17412 2017-01-03 22:00:00  2017    01  03     224          5.5
# 17413 2017-01-03 23:00:00  2017    01  03     139          5.0
#
#        temperature_feels    hum  wind_speed  weather_code  is_holiday  \
# 0                    2.0   93.0         6.0           3.0         0.0
# 1                    2.5   93.0         5.0           1.0         0.0
# 2                    2.5   96.5         0.0           1.0         0.0
# 3                    2.0  100.0         0.0           1.0         0.0
# 4                    0.0   93.0         6.5           1.0         0.0
# ...                  ...    ...         ...           ...         ...
# 17409                1.0   81.0        19.0           3.0         0.0
# 17410                1.0   81.0        21.0           4.0         0.0
# 17411                1.5   78.5        24.0           4.0         0.0
# 17412                1.5   76.0        23.0           4.0         0.0
# 17413                1.0   76.0        22.0           2.0         0.0
#
#        is_weekend  season day_name week_number
# 0             1.0     3.0   Sunday          01
# 1             1.0     3.0   Sunday          01
# 2             1.0     3.0   Sunday          01
# 3             1.0     3.0   Sunday          01
# 4             1.0     3.0   Sunday          01
# ...           ...     ...      ...         ...
# 17409         0.0     3.0  Tuesday          01
# 17410         0.0     3.0  Tuesday          01
# 17411         0.0     3.0  Tuesday          01
# 17412         0.0     3.0  Tuesday          01
# 17413         0.0     3.0  Tuesday          01
#
# [17414 rows x 15 columns]

# %% [markdown]
# * Reorganizing the columns again

# %%
df.columns
# Out:
# Index(['timestamp', 'year', 'month', 'day', 'number', 'temperature',
#        'temperature_feels', 'hum', 'wind_speed', 'weather_code', 'is_holiday',
#        'is_weekend', 'season', 'day_name', 'week_number'],
#       dtype='object')

# %%
column_names = ['timestamp', 'year', 'month', 'day', 'day_name', 'week_number', 'number', 'temperature',
       'temperature_feels', 'hum', 'wind_speed', 'weather_code', 'is_holiday',
       'is_weekend', 'season']

# %%
df = df.reindex(columns=column_names)

# %%
df
# Out:
#                 timestamp  year month day day_name week_number  number  \
# 0     2015-01-04 00:00:00  2015    01  04   Sunday          01     182
# 1     2015-01-04 01:00:00  2015    01  04   Sunday          01     138
# 2     2015-01-04 02:00:00  2015    01  04   Sunday          01     134
# 3     2015-01-04 03:00:00  2015    01  04   Sunday          01      72
# 4     2015-01-04 04:00:00  2015    01  04   Sunday          01      47
# ...                   ...   ...   ...  ..      ...         ...     ...
# 17409 2017-01-03 19:00:00  2017    01  03  Tuesday          01    1042
# 17410 2017-01-03 20:00:00  2017    01  03  Tuesday          01     541
# 17411 2017-01-03 21:00:00  2017    01  03  Tuesday          01     337
# 17412 2017-01-03 22:00:00  2017    01  03  Tuesday          01     224
# 17413 2017-01-03 23:00:00  2017    01  03  Tuesday          01     139
#
#        temperature  temperature_feels    hum  wind_speed  weather_code  \
# 0              3.0                2.0   93.0         6.0           3.0
# 1              3.0                2.5   93.0         5.0           1.0
# 2              2.5                2.5   96.5         0.0           1.0
# 3              2.0                2.0  100.0         0.0           1.0
# 4              2.0                0.0   93.0         6.5           1.0
# ...            ...                ...    ...         ...           ...
# 17409          5.0                1.0   81.0        19.0           3.0
# 17410          5.0                1.0   81.0        21.0           4.0
# 17411          5.5                1.5   78.5        24.0           4.0
# 17412          5.5                1.5   76.0        23.0           4.0
# 17413          5.0                1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 15 columns]

# %%
df
# Out:
#                 timestamp  year month day day_name week_number  number  \
# 0     2015-01-04 00:00:00  2015    01  04   Sunday          01     182
# 1     2015-01-04 01:00:00  2015    01  04   Sunday          01     138
# 2     2015-01-04 02:00:00  2015    01  04   Sunday          01     134
# 3     2015-01-04 03:00:00  2015    01  04   Sunday          01      72
# 4     2015-01-04 04:00:00  2015    01  04   Sunday          01      47
# ...                   ...   ...   ...  ..      ...         ...     ...
# 17409 2017-01-03 19:00:00  2017    01  03  Tuesday          01    1042
# 17410 2017-01-03 20:00:00  2017    01  03  Tuesday          01     541
# 17411 2017-01-03 21:00:00  2017    01  03  Tuesday          01     337
# 17412 2017-01-03 22:00:00  2017    01  03  Tuesday          01     224
# 17413 2017-01-03 23:00:00  2017    01  03  Tuesday          01     139
#
#        temperature  temperature_feels    hum  wind_speed  weather_code  \
# 0              3.0                2.0   93.0         6.0           3.0
# 1              3.0                2.5   93.0         5.0           1.0
# 2              2.5                2.5   96.5         0.0           1.0
# 3              2.0                2.0  100.0         0.0           1.0
# 4              2.0                0.0   93.0         6.5           1.0
# ...            ...                ...    ...         ...           ...
# 17409          5.0                1.0   81.0        19.0           3.0
# 17410          5.0                1.0   81.0        21.0           4.0
# 17411          5.5                1.5   78.5        24.0           4.0
# 17412          5.5                1.5   76.0        23.0           4.0
# 17413          5.0                1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 15 columns]

# %% [markdown]
# * Changing number of month to name of the month

# %%
df['month'] = pd.to_datetime(df['month'], format='%m').dt.month_name().str.slice(stop=3)

# %%
df.to_csv('london_merged_v1.csv')

# %% [markdown]
# ### Saving the updates and cleanning in a new Data Set

# %%
df = pd.read_csv('london_merged_v1.csv')

# %%
df = df.reset_index()

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.to_csv('london_merged_v1.csv', index=False)

# %%
df = pd.read_csv('london_merged_v1.csv')
